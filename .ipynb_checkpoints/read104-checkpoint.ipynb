# %%
import fitz
import csv
import os
import numpy as np

# %%
contenido = os.listdir('form104')
contenido
# Out:
# ['104 ABRIL.pdf',
#  '104 AGOS.pdf',
#  '104 DIC.pdf',
#  '104 ENERO.pdf',
#  '104 FEBRERO.pdf',
#  '104 JULIO.pdf',
#  '104 JUNIO.pdf',
#  '104 MARZO.pdf',
#  '104 MAYO.pdf',
#  '104 NOV.pdf',
#  '104 OCT.pdf',
#  '104 SEPT.pdf']

# %%
v = 0

per = ""

valcod401=0
valcod411=0
valcod421=0

valcod402=0
valcod412=0
valcod422=0

valcod403=0
valcod413=0

valcod404=0
valcod414=0

valcod405=0
valcod415=0

valcod406=0
valcod416=0

valcod407=0
valcod417=0

valcod408=0
valcod418=0

valcod409=0
valcod419=0
valcod429=0
#################################################

valcod500=0
valcod510=0
valcod520=0

valcod501=0
valcod511=0
valcod521=0

valcod502=0
valcod512=0
valcod522=0


valcod503=0
valcod513=0
valcod523=0

valcod504=0
valcod514=0
valcod524=0

valcod505=0
valcod515=0
valcod525=0

valcod506=0
valcod516=0

valcod507=0
valcod517=0

valcod508=0
valcod518=0

valcod509=0
valcod519=0
valcod529=0

####Totales

total401=0
total411=0
total421=0

total402=0
total412=0
total422=0

total403=0
total413=0

total404=0
total414=0

total405=0
total415=0

total406=0
total416=0

total407=0
total417=0

total408=0
total418=0

total409=0
total419=0
total429=0
#----------------------

total500=0
total510=0
total520=0

total501=0
total511=0
total521=0

total502=0
total512=0
total522=0

total503=0
total513=0
total523=0

total504=0
total514=0
total524=0

total505=0
total515=0
total525=0

total506=0
total516=0

total507=0
total517=0

total508=0
total518=0

total509=0
total519=0
total529=0



codigos = []
total = []

cabecera = ['411','421','402','412','422','403','413','404','414','405','415','406','416','407','417','408','418',
'409','419','429','500','510','520','501','511','521','502','512','522','503','513','523','504','514','524','505','515',
'525','506','516','507','517','508','518','509','519','529','401','411','421','402','412','422','403','413','404','414',
'405','415','406','416','407','417','408','418','409','419','429','500','510','520','501','511','521','502','512','522',
'503','513','523','504','514','524','505','515','525','506','516','507','517','508','518','509','519','529']
codigos.append(cabecera)


for arch in contenido:
    pag = []
    pdf_documento = "form104/"+contenido[v]
    print(str(pdf_documento))
    v+=1
    documento = fitz.open(pdf_documento)
    #print("N paginas", documento.pageCount)
    #print("Metadatos ", documento.metadata)
    
    pagina = documento.loadPage(0)
    text = pagina.getText("Text")
    
    separador = "\n"
    separado = text.split(separador)
    print(separado)
    con = 0
    
    for it in separado:
        
        if it == "Período Fiscal:":
            per = separado[con+1]
        if it=="401":
            valcod401 = separado[con+1]
            print(valcod401)
        if it=="411":
            tempcod411 = separado[con+1]
            v411 = str(tempcod411).split()
            print(v411)
            valcod411 = v411[0]
            print(valcod411)
        if it=="421":
            valcod421 = separado[con+1]
            
        if it=="402":
            valcod402 = separado[con+1]
            print("402")
            print(valcod402)
        if it=="412":
            tempcod412 = separado[con+1]
            v412 = str(tempcod412).split()
            valcod412 = v412[0]
            print(valcod412)
        if it=="422":
            valcod422 = separado[con+1]
            
        if it=="403":
            valcod403 = separado[con+1]
        if it=="413":
            valcod413 = separado[con+1]
            
        if it=="404":
            valcod404 = separado[con+1]
        if it=="414":
            valcod414 = separado[con+1]
            
        if it=="405":
            valcod405 = separado[con+1]
        if it=="415":
            valcod415 = separado[con+1]
            
        if it=="406":
            valcod406 = separado[con+1]
        if it=="416":
            valcod416 = separado[con+1]
            
        if it=="407":
            valcod407 = separado[con+1]
        if it=="417":
            valcod417= separado[con+1]
            
        if it=="408":
            valcod408= separado[con+1]
        if it=="418":
            valcod418= separado[con+1]
            
        if it=="409":
            valcod409= separado[con+1]
        if it=="419":
            tempcod419 = separado[con+1]
            v419 = str(tempcod419).split()
            valcod419 = v419[0]
            print(valcod419)
        if it=="429":
            valcod429= separado[con+1]
        
        con+=1
        
    pag.append("Período Fiscal: "+per+";")
    pag.append(float(valcod401))
    pag.append(float(valcod411))
    pag.append(float(valcod421))

    pag.append(float(valcod402))
    pag.append(float(valcod412))
    pag.append(float(valcod422))
    
    pag.append(float(valcod403))
    pag.append(float(valcod413))
    
    pag.append(float(valcod404))
    pag.append(float(valcod414))
    
    pag.append(float(valcod405))
    pag.append(float(valcod415))
    
    pag.append(float(valcod406))
    pag.append(float(valcod416))
    
    pag.append(float(valcod407))
    pag.append(float(valcod417))
    
    pag.append(float(valcod408))
    pag.append(float(valcod418))
    
    pag.append(float(valcod409))
    pag.append(float(valcod419))
    pag.append(float(valcod429))
    
    total401=float(total401)+float(valcod401)
    total411=float(total411)+float(valcod411)
    total421=float(total421)+float(valcod421)

    total402=float(total402)+float(valcod402)
    total412=float(total412)+float(valcod412)
    total422=float(total422)+float(valcod422)
    
    total403=float(total403)+float(valcod403)
    total413=float(total413)+float(valcod413)
    
    total404=float(total404)+float(valcod404)
    total414=float(total414)+float(valcod414)
    
    total405=float(total405)+float(valcod405)
    total415=float(total415)+float(valcod415)
    
    total406=float(total406)+float(valcod406)
    total416=float(total416)+float(valcod416)
    
    total407=float(total407)+float(valcod407)
    total417=float(total417)+float(valcod417)
    
    total408=float(total408)+float(valcod408)
    total418=float(total418)+float(valcod418)
    
    total409=float(total409)+float(valcod409)
    total419=float(total419)+float(valcod419)
    total429=float(total429)+float(valcod429)

        
    pagina = documento.loadPage(1)
    text = pagina.getText("Text")
    
    separador = "\n"
    separado = text.split(separador)
    print(separado)
    con = 0
    
    for it in separado:
        if it=="500":
            valcod500 = separado[con+1]
        if it=="510":
            tempcod510 = separado[con+1]
            v510 = str(tempcod510).split()
            valcod510 = v510[0]
            print(valcod510)
        if it=="520":
            valcod520 = separado[con+1]

        if it=="501":
            valcod501 = separado[con+1]
        if it=="511":
            tempcod511 = separado[con+1]
            v511 = str(tempcod511).split()
            valcod511 = v511[0]
            print(valcod511)
        if it=="521":
            valcod521= separado[con+1]
            
        if it=="502":
            valcod502= separado[con+1]
        if it=="512":
            tempc512= separado[con+1]
            v512 = str(tempc512).split()
            valcod512 = v512[0]
        if it=="522":
            valcod522= separado[con+1]
            
        if it=="503":
            valcod503= separado[con+1]
        if it=="513":
            tempcod513= separado[con+1]
            v513 = str(tempcod513).split()
            valcod513 = v513[0]
            print(valcod513)
        if it=="523":
            valcod523= separado[con+1]
            
        if it=="504":
            valcod504= separado[con+1]
        if it=="514":
            tempcod514 = separado[con+1]
            v514 = str(tempcod514).split()
            valcod514 = v514[0]
            print(valcod514)
        if it=="524":
            valcod524 = separado[con+1]
            
        if it=="505":
            valcod505 = separado[con+1]
        if it=="515":
            tempcod515 = separado[con+1]
            v515 = str(tempcod515).split()
            valcod515 = v515[0]
            print(valcod515)
        if it=="525":
            valcod525 = separado[con+1]
            
        if it=="506":
            valcod506 = separado[con+1]
        if it=="516":
            valcod516 = separado[con+1]
            
        if it=="507":
            valcod507 = separado[con+1]
        if it=="517":
            valcod517 = separado[con+1]
            
        if it=="508":
            valcod508 = separado[con+1]
        if it=="518":
            valcod518 = separado[con+1]
            
        if it=="509":
            valcod509 = separado[con+1]
        if it=="519":
            tempcod519 = separado[con+1]
            v519 = str(tempcod519).split()
            valcod519 = v519[0]
            print(valcod519)
        if it=="529":
            valcod529 = separado[con+1]
        con+=1
            
    total500=total500+float(valcod500)
    total510=total510+float(valcod510)
    total520=total520+float(valcod520)
    
    total501=total501+float(valcod501)
    total511=total511+float(valcod511)
    total521=total521+float(valcod521)
    
    total502=total502+float(valcod502)
    total512=total512+float(valcod512)
    total522=total522+float(valcod522)
    
    total503=total503+float(valcod503)
    total513=total513+float(valcod513)
    total523=total523+float(valcod523)
    
    total504=total504+float(valcod504)
    total514=total514+float(valcod514)
    total524=total524+float(valcod524)
    
    total505=total505+float(valcod505)
    total515=total515+float(valcod515)
    total525=total525+float(valcod525)
    
    total506=total506+float(valcod506)
    total516=total516+float(valcod516)
    
    total507=total507+float(valcod507)
    total517=total517+float(valcod517)
    
    total508=total508+float(valcod508)
    total518=total518+float(valcod518)
    
    total509=total509+float(valcod509)
    total519=total519+float(valcod519)
    total529=total529+float(valcod529)
            
    pag.append(float(valcod500))
    pag.append(float(valcod510))
    pag.append(float(valcod520))
    
    pag.append(float(valcod501))
    pag.append(float(valcod511))
    pag.append(float(valcod521))
    
    pag.append(float(valcod502))
    pag.append(float(valcod512))
    pag.append(float(valcod522))
    
    pag.append(float(valcod503))
    pag.append(float(valcod513))
    pag.append(float(valcod523))
    
    pag.append(float(valcod504))
    pag.append(float(valcod514))
    pag.append(float(valcod524))
    
    pag.append(float(valcod505))
    pag.append(float(valcod515))
    pag.append(float(valcod525))
    
    pag.append(float(valcod506))
    pag.append(float(valcod516))
    
    pag.append(float(valcod507))
    pag.append(float(valcod517))
    
    pag.append(float(valcod508))
    pag.append(float(valcod518))
    
    pag.append(float(valcod509))
    pag.append(float(valcod519))
    pag.append(float(valcod529))
    
    
    
    codigos.append(pag)
    
total.append("Total ;")
total.append(float(total401))
total.append(float(total411))
total.append(float(total421))

total.append(float(total402))
total.append(float(total412))
total.append(float(total422))
    
total.append(float(total403))
total.append(float(total413))

total.append(float(total404))
total.append(float(total414))

total.append(float(total405))
total.append(float(total415))

total.append(float(total406))
total.append(float(total416))

total.append(float(total407))
total.append(float(total417))

total.append(float(total408))
total.append(float(total418))

total.append(float(total409))
total.append(float(total419))
total.append(float(total429))

total.append(float(total500))
total.append(float(total510))
total.append(float(total520))

total.append(float(total501))
total.append(float(total511))
total.append(float(total521))

total.append(float(total502))
total.append(float(total512))
total.append(float(total522))

total.append(float(total503))
total.append(float(total513))
total.append(float(total523))

total.append(float(total504))
total.append(float(total514))
total.append(float(total524))

total.append(float(total505))
total.append(float(total515))
total.append(float(total525))

total.append(float(total506))
total.append(float(total516))

total.append(float(total507))
total.append(float(total517))

total.append(float(total508))
total.append(float(total518))

total.append(float(total509))
total.append(float(total519))
total.append(float(total529))

codigos.append(total)
# Out:
# form104/104 ABRIL.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020036782787', '871996319206', '14-05-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'ABRIL 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '5303.89', '411', '5269.66', '421', '632.36', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '4532.53', '415', '4531.01', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '9836.42', '419', '9800.67', '429', '632.36', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 5303.89
# ['5269.66']
# 5269.66
# 402
# 0.00
# 0.00
# 9800.67
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020036782787', '871996319206', '14-05-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '0.00', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '5269.66', 'Total impuesto generado', '(trasládese campo 429)', '482', '632.36', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '536.84', 'Impuesto a liquidar en este mes', '484', '0.00', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '632.36', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '536.84', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '732.89', '510', '302.89', '520', '36.35', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '424.00', '517', '424.00', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '2433.50', '518', '2433.50', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '3590.39', '519', '3160.39', '529', '36.35', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 302.89
# 0.00
# 0.00
# 0.00
# 0.00
# 3160.39
# form104/104 AGOS.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020042383550', '872056831616', '14-09-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'AGOSTO 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '12344.75', '411', '12335.55', '421', '1480.27', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '6973.03', '415', '6894.82', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '19317.78', '419', '19230.37', '429', '1480.27', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 12344.75
# ['12335.55']
# 12335.55
# 402
# 0.00
# 0.00
# 19230.37
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020042383550', '872056831616', '14-09-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '0.00', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '12335.55', 'Total impuesto generado', '(trasládese campo 429)', '482', '1480.27', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '0.00', 'Impuesto a liquidar en este mes', '484', '0.00', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '1480.27', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '0.00', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '1668.77', '510', '1668.77', '520', '200.25', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '124.43', '517', '124.43', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '4950.00', '518', '4950.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '6743.20', '519', '6743.20', '529', '200.25', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 1668.77
# 0.00
# 0.00
# 0.00
# 0.00
# 6743.20
# form104/104 DIC.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2021050391833', '872111203894', '14-01-2021', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'DICIEMBRE 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '29934.15', '411', '29934.15', '421', '3592.10', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '19634.83', '415', '19634.83', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '49568.98', '419', '49568.98', '429', '3592.10', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 29934.15
# ['29934.15']
# 29934.15
# 402
# 0.00
# 0.00
# 49568.98
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2021050391833', '872111203894', '14-01-2021', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '0.00', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '29934.15', 'Total impuesto generado', '(trasládese campo 429)', '482', '3592.10', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '0.00', 'Impuesto a liquidar en este mes', '484', '0.00', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '3592.10', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '0.00', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '5489.72', '510', '5489.21', '520', '658.71', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '6821.09', '517', '6821.09', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '0.00', '518', '0.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '12310.81', '519', '12310.30', '529', '658.71', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 5489.21
# 0.00
# 0.00
# 0.00
# 0.00
# 12310.30
# form104/104 ENERO.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2021054249293', '872150882491', '15-03-2021', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'ENERO 2020', 'Tipo Declaración:', 'SUSTITUTIVA', 'Formulario Sustituye:', '871950980337', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '3625.33', '411', '3625.33', '421', '435.04', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '9361.69', '415', '9361.69', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '12987.02', '419', '12987.02', '429', '435.04', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 3625.33
# ['3625.33']
# 3625.33
# 402
# 0.00
# 0.00
# 12987.02
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2021054249293', '872150882491', '15-03-2021', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '3625.33', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '0.00', 'Total impuesto generado', '(trasládese campo 429)', '482', '435.04', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '0.00', 'Impuesto a liquidar en este mes', '484', '435.04', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '0.00', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '435.04', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '2345.52', '510', '2345.52', '520', '281.46', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '2606.42', '517', '2606.42', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '4942.79', '518', '4942.79', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '9894.73', '519', '9894.73', '529', '281.46', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 2345.52
# 0.00
# 0.00
# 0.00
# 0.00
# 9894.73
# form104/104 FEBRERO.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020032628233', '871971104234', '16-03-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'FEBRERO 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '8750.80', '411', '8708.53', '421', '1045.02', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '7446.36', '413', '7382.36', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '0.00', '415', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '16197.16', '419', '16090.89', '429', '1045.02', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', 'LIQUIDACIÓN DEL IVA EN EL MES', '']
# 8750.80
# ['8708.53']
# 8708.53
# 402
# 0.00
# 0.00
# 16090.89
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020032628233', '871971104234', '16-03-2020', 'PÁGINA', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '5208.53', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '3500.00', 'Total impuesto generado', '(trasládese campo 429)', '482', '1045.02', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '0.00', 'Impuesto a liquidar en este mes', '484', '625.02', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '420.00', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '625.02', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '1034.81', '510', '1034.81', '520', '124.18', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '90.00', '517', '0.00', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '0.00', '518', '0.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '1124.81', '519', '1034.81', '529', '124.18', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', 'Notas de crédito tarifa  diferente de cero por compensar próximo mes', '.', '544', '0.00', '554', '0.00', '']
# 1034.81
# 0.00
# 0.00
# 0.00
# 0.00
# 1034.81
# form104/104 JULIO.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020040871711', '872043014167', '14-08-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'JULIO 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '12015.52', '411', '11528.89', '421', '1383.47', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '9553.38', '415', '9553.38', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '21568.90', '419', '21082.27', '429', '1383.47', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 12015.52
# ['11528.89']
# 11528.89
# 402
# 0.00
# 0.00
# 21082.27
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020040871711', '872043014167', '14-08-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '11528.89', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '0.00', 'Total impuesto generado', '(trasládese campo 429)', '482', '1383.47', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '966.28', 'Impuesto a liquidar en este mes', '484', '1383.47', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '0.00', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '2349.75', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '2342.40', '510', '2342.40', '520', '281.09', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '810.38', '517', '810.38', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '4950.00', '518', '4950.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '8102.78', '519', '8102.78', '529', '281.09', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 2342.40
# 0.00
# 0.00
# 0.00
# 0.00
# 8102.78
# form104/104 JUNIO.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020039571189', '872026582632', '14-07-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'JUNIO 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '8052.33', '411', '8052.33', '421', '966.28', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '10483.12', '415', '10483.12', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '18535.45', '419', '18535.45', '429', '966.28', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 8052.33
# ['8052.33']
# 8052.33
# 402
# 0.00
# 0.00
# 18535.45
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020039571189', '872026582632', '14-07-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '0.00', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '8052.33', 'Total impuesto generado', '(trasládese campo 429)', '482', '966.28', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '277.44', 'Impuesto a liquidar en este mes', '484', '0.00', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '966.28', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '277.44', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '2585.76', '510', '2585.76', '520', '310.29', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '0.00', '517', '0.00', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '4950.00', '518', '4950.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '7535.76', '519', '7535.76', '529', '310.29', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 2585.76
# 0.00
# 0.00
# 0.00
# 0.00
# 7535.76
# form104/104 MARZO.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020036789305', '871982677015', '14-04-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'MARZO 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '7262.47', '411', '4473.70', '421', '536.84', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '6577.82', '413', '6577.82', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '0.00', '415', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '13840.29', '419', '11051.52', '429', '536.84', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', 'LIQUIDACIÓN DEL IVA EN EL MES', '']
# 7262.47
# ['4473.70']
# 4473.70
# 402
# 0.00
# 0.00
# 11051.52
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020036789305', '871982677015', '14-04-2020', 'PÁGINA', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '0.00', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '4473.70', 'Total impuesto generado', '(trasládese campo 429)', '482', '536.84', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '420.00', 'Impuesto a liquidar en este mes', '484', '0.00', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '536.84', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '420.00', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '1122.53', '510', '1122.53', '520', '134.70', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '151.77', '517', '151.77', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '1729.00', '518', '1729.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '3003.30', '519', '3003.30', '529', '134.70', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', 'Notas de crédito tarifa  diferente de cero por compensar próximo mes', '.', '544', '0.00', '554', '0.00', '']
# 1122.53
# 0.00
# 0.00
# 0.00
# 0.00
# 3003.30
# form104/104 MAYO.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020036789313', '872010549017', '15-06-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'MAYO 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '2312.01', '411', '2312.01', '421', '277.44', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '4561.23', '415', '4561.23', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '6873.24', '419', '6873.24', '429', '277.44', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 2312.01
# ['2312.01']
# 2312.01
# 402
# 0.00
# 0.00
# 6873.24
# ...
# 10219.14
# ['10219.14']
# 10219.14
# 402
# 0.00
# 0.00
# 22792.52
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2021046731312', '872095640612', '14-12-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '10219.14', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '0.00', 'Total impuesto generado', '(trasládese campo 429)', '482', '1226.30', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '300.00', 'Impuesto a liquidar en este mes', '484', '1226.30', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '0.00', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '1526.30', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '8329.82', '510', '8329.82', '520', '999.58', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '1034.61', '517', '1034.61', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '0.00', '518', '0.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '9364.43', '519', '9364.43', '529', '999.58', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 8329.82
# 0.00
# 0.00
# 0.00
# 0.00
# 9364.43
# form104/104 OCT.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020045292190', '872083861036', '16-11-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'OCTUBRE 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '10791.17', '411', '10791.17', '421', '1294.94', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '8987.38', '415', '8987.38', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '19778.55', '419', '19778.55', '429', '1294.94', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 10791.17
# ['10791.17']
# 10791.17
# 402
# 0.00
# 0.00
# 19778.55
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020045292190', '872083861036', '16-11-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '8291.17', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '2500.00', 'Total impuesto generado', '(trasládese campo 429)', '482', '1294.94', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '278.97', 'Impuesto a liquidar en este mes', '484', '994.94', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '300.00', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '1273.91', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '2259.56', '510', '2156.16', '520', '258.74', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '96.53', '517', '96.53', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '7555.00', '518', '7555.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '9911.09', '519', '9807.69', '529', '258.74', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 2156.16
# 0.00
# 0.00
# 0.00
# 0.00
# 9807.69
# form104/104 SEPT.pdf
# ['1', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020043039178', '872069810372', '14-10-2020', 'PÁGINA', 'Obligación Tributaria:', '2011  DECLARACION DE IVA', 'Identificación:', '0190334732001', 'Razón Social:', 'FLAMASEG CIA LTDA AGENCIA ASESORA PRODUCTORA DE SEGUROS', 'Período Fiscal:', 'SEPTIEMBRE 2020', 'Tipo Declaración:', 'ORIGINAL', 'Formulario Sustituye:', 'RESUMEN DE VENTAS Y OTRAS OPERACIONES DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa diferente de cero', '401', '6071.11', '411', '6046.37', '421', '725.56', 'Ventas de activos fijos gravadas tarifa diferente de cero', '402', '0.00', '412', '0.00', '422', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a pagar)', '.', '423', '0.00', 'IVA generado en la diferencia entre ventas y notas de crédito con distinta tarifa (ajuste a favor)', '.', '424', '0.00', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que no dan derecho a crédito tributario', '403', '0.00', '413', '0.00', '.', 'Ventas de activos fijos gravadas tarifa 0% que no dan derecho a crédito tributario', '404', '0.00', '414', '0.00', '.', 'Ventas locales (excluye activos fijos) gravadas tarifa 0% que dan derecho a crédito tributario', '405', '8444.47', '415', '8444.47', '.', 'Ventas de activos fijos gravadas tarifa 0% que dan derecho a crédito tributario', '406', '0.00', '416', '0.00', '.', 'Exportaciones de bienes', '407', '0.00', '417', '0.00', '.', 'Exportaciones de servicios y/o derechos', '408', '0.00', '418', '0.00', '.', 'TOTAL VENTAS Y OTRAS OPERACIONES', '409', '14515.58', '419', '14490.84', '429', '725.56', 'Transferencias no objeto o exentas de IVA', '431', '0.00', '441', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '442', '0.00', '.', 'Notas de crédito tarifa diferente de cero por compensar próximo mes', '.', '443', '0.00', '453', '0.00', 'Ingresos por reembolso como intermediario / valores facturados por operadoras de transporte / ingresos obtenidos por', 'parte de las sociedades de gestión colectiva como intermediarios (informativo)', '434', '0.00', '444', '0.00', '454', '0.00', '.', '']
# 6071.11
# ['6046.37']
# 6046.37
# 402
# 0.00
# 0.00
# 14490.84
# ['2', 'La información reposa en la base de datos del SRI, conforme la declaraciónrealizada por el contribuyente', 'CÓDIGO VERIFICADOR', 'NÚMERO SERIAL', 'FECHA RECAUDACIÓN', 'SRIDEC2020043039178', '872069810372', '14-10-2020', 'PÁGINA', 'LIQUIDACIÓN DEL IVA EN EL MES', 'Total transferencias gravadas tarifa diferente de cero a contado este mes', '480', '3721.60', 'Total transferencias gravadas tarifa diferente de cero a crédito este mes', '481', '2324.77', 'Total impuesto generado', '(trasládese campo 429)', '482', '725.56', 'Impuesto a liquidar del mes anterior', '(trasládese el campo 485 de la', 'declaración del período anterior)', '483', '1480.27', 'Impuesto a liquidar en este mes', '484', '446.59', 'Impuesto a liquidar en el próximo mes', '482-484', '485', '278.97', 'TOTAL IMPUESTO A LIQUIDAR EN ESTE MES', '483+484', '499', '1926.86', 'Total comprobantes de venta emitidos', '111', '0', '.', 'Total comprobantes de venta anulados', '113', '0', 'RESUMEN DE ADQUISICIONES Y PAGOS DEL PERÍODO QUE DECLARA', 'VALOR BRUTO', 'VALOR NETO', 'IMPUESTO', 'GENERADO', '.', '(VALOR BRUTO -', 'N/C)', '.', 'Adquisiciones y pagos (excluye activos fijos) gravados tarifa diferente de cero (con derecho a crédito tributario)', '500', '2101.50', '510', '2101.50', '520', '252.18', 'Adquisiciones locales de activos fijos gravados tarifa diferente de cero (con derecho a crédito tributario)', '501', '0.00', '511', '0.00', '521', '0.00', 'Otras adquisiciones y pagos gravados tarifa diferente de cero (sin derecho a crédito tributario)', '502', '0.00', '512', '0.00', '522', '0.00', 'Importaciones de servicios y/o derechos gravados tarifa diferente de cero', '503', '0.00', '513', '0.00', '523', '0.00', 'Importaciones de bienes (excluye activos fijos) gravados tarifa diferente de cero', '504', '0.00', '514', '0.00', '524', '0.00', 'Importaciones de activos fijos gravados tarifa diferente de cero', '505', '0.00', '515', '0.00', '525', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en positivo al crédito', 'tributario)', '.', '526', '0.00', 'IVA generado en la diferencia entre adquisiciones y notas de crédito con distinta tarifa (ajuste en negativo al crédito', 'tributario)', '.', '527', '0.00', 'Importaciones de bienes (incluye activos fijos) gravados tarifa 0%', '506', '0.00', '516', '0.00', '.', 'Adquisiciones y pagos (incluye activos fijos) gravados tarifa 0%', '507', '86.81', '517', '86.81', '.', 'Adquisiciones realizadas a contribuyentes RISE', '508', '4950.00', '518', '4950.00', '.', 'TOTAL ADQUISICIONES Y PAGOS', '509', '7138.31', '519', '7138.31', '529', '252.18', 'Adquisiciones no objeto de IVA', '531', '0.00', '541', '0.00', '.', 'Adquisiciones exentas del pago de IVA', '532', '0.00', '542', '0.00', '.', 'Notas de crédito tarifa 0% por compensar próximo mes', '.', '543', '0.00', '.', '']
# 2101.50
# 0.00
# 0.00
# 0.00
# 0.00
# 7138.31

# %%
    '''myData = [['302',valcod302],
              [cod340, ';', valcod340],
    ['Tom', 'Smith', 'B']],[['ddd']]

    print(codigos)

    myData = codigos
    myFile = open('reporte104.csv', 'w')
    with myFile:
        writer = csv.writer(myFile)
        writer.writerows(myData)

    print("Writing complete")'''
# Out:
# [['Período Fiscal: ABRIL 2020;', '401: 5303.89;', '411: 5269.66;', '421: 632.36;', '402: 0.00;', '412: 0.00;', '422: 0.00;', '403: 0.00;', '413: 0.00;', '404: 0.00;', '414: 0.00;', '405: 4532.53;', '415: 4531.01;', '406: 0.00;', '416: 0.00;', '407: 0.00;', '417: 0.00;', '408: 0.00;', '418: 0.00;', '409: 9836.42;', '419: 9800.67;', '429: 632.36;', '500: 732.89;', '510: 302.89;', '520: 36.35;', '501: 0.00;', '511: 0.00;', '521: 0.00;', '502: 0.00;', '512: 0.00;', '522: 0.00;', '503: 0.00;', '513: 0.00;', '523: 0.00;', '504: 0.00;', '514: 0.00;', '524: 0.00;', '505: 0.00;', '525: 0.00;', '525: 0.00;', '506: 0.00;', '516: 0.00;', '507: 424.00;', '517: 424.00;', '508: 2433.50;', '518: 2433.50;', '509: 3590.39;', '519: 3160.39;', '529: 36.35;'], ['Período Fiscal: AGOSTO 2020;', '401: 12344.75;', '411: 12335.55;', '421: 1480.27;', '402: 0.00;', '412: 0.00;', '422: 0.00;', '403: 0.00;', '413: 0.00;', '404: 0.00;', '414: 0.00;', '405: 6973.03;', '415: 6894.82;', '406: 0.00;', '416: 0.00;', '407: 0.00;', '417: 0.00;', '408: 0.00;', '418: 0.00;', '409: 19317.78;', '419: 19230.37;', '429: 1480.27;', '500: 1668.77;', '510: 1668.77;', '520: 200.25;', '501: 0.00;', '511: 0.00;', '521: 0.00;', '502: 0.00;', '512: 0.00;', '522: 0.00;', '503: 0.00;', '513: 0.00;', '523: 0.00;', '504: 0.00;', '514: 0.00;', '524: 0.00;', '505: 0.00;', '525: 0.00;', '525: 0.00;', '506: 0.00;', '516: 0.00;', '507: 124.43;', '517: 124.43;', '508: 4950.00;', '518: 4950.00;', '509: 6743.20;', '519: 6743.20;', '529: 200.25;'], ['Período Fiscal: DICIEMBRE 2020;', '401: 29934.15;', '411: 29934.15;', '421: 3592.10;', '402: 0.00;', '412: 0.00;', '422: 0.00;', '403: 0.00;', '413: 0.00;', '404: 0.00;', '414: 0.00;', '405: 19634.83;', '415: 19634.83;', '406: 0.00;', '416: 0.00;', '407: 0.00;', '417: 0.00;', '408: 0.00;', '418: 0.00;', '409: 49568.98;', '419: 49568.98;', '429: 3592.10;', '500: 5489.72;', '510: 5489.21;', '520: 658.71;', '501: 0.00;', '511: 0.00;', '521: 0.00;', '502: 0.00;', '512: 0.00;', '522: 0.00;', '503: 0.00;', '513: 0.00;', '523: 0.00;', '504: 0.00;', '514: 0.00;', '524: 0.00;', '505: 0.00;', '525: 0.00;', '525: 0.00;', '506: 0.00;', '516: 0.00;', '507: 6821.09;', '517: 6821.09;', '508: 0.00;', '518: 0.00;', '509: 12310.81;', '519: 12310.30;', '529: 658.71;'], ['Período Fiscal: ENERO 2020;', '401: 3625.33;', '411: 3625.33;', '421: 435.04;', '402: 0.00;', '412: 0.00;', '422: 0.00;', '403: 0.00;', '413: 0.00;', '404: 0.00;', '414: 0.00;', '405: 9361.69;', '415: 9361.69;', '406: 0.00;', '416: 0.00;', '407: 0.00;', '417: 0.00;', '408: 0.00;', '418: 0.00;', '409: 12987.02;', '419: 12987.02;', '429: 435.04;', '500: 2345.52;', '510: 2345.52;', '520: 281.46;', '501: 0.00;', '511: 0.00;', '521: 0.00;', '502: 0.00;', '512: 0.00;', '522: 0.00;', '503: 0.00;', '513: 0.00;', '523: 0.00;', '504: 0.00;', '514: 0.00;', '524: 0.00;', '505: 0.00;', '525: 0.00;', '525: 0.00;', '506: 0.00;', '516: 0.00;', '507: 2606.42;', '517: 2606.42;', '508: 4942.79;', '518: 4942.79;', '509: 9894.73;', '519: 9894.73;', '529: 281.46;'], ['Período Fiscal: FEBRERO 2020;', '401: 8750.80;', '411: 8708.53;', '421: 1045.02;', '402: 0.00;', '412: 0.00;', '422: 0.00;', '403: 7446.36;', '413: 7382.36;', '404: 0.00;', '414: 0.00;', '405: 0.00;', '415: 0.00;', '406: 0.00;', '416: 0.00;', '407: 0.00;', '417: 0.00;', '408: 0.00;', '418: 0.00;', '409: 16197.16;', '419: 16090.89;', '429: 1045.02;', '500: 1034.81;', '510: 1034.81;', '520: 124.18;', '501: 0.00;', '511: 0.00;', '521: 0.00;', '502: 0.00;', '512: 0.00;', '522: 0.00;', '503: 0.00;', '513: 0.00;', '523: 0.00;', '504: 0.00;', '514: 0.00;', '524: 0.00;', '505: 0.00;', '525: 0.00;', '525: 0.00;', '506: 0.00;', '516: 0.00;', '507: 90.00;', '517: 0.00;', '508: 0.00;', '518: 0.00;', '509: 1124.81;', '519: 1034.81;', '529: 124.18;'], ['Período Fiscal: JULIO 2020;', '401: 12015.52;', '411: 11528.89;', '421: 1383.47;', '402: 0.00;', '412: 0.00;', '422: 0.00;', '403: 0.00;', '413: 0.00;', '404: 0.00;', '414: 0.00;', '405: 9553.38;', '415: 9553.38;', '40 ...
# Writing complete

# %%
import openpyxl
wb = openpyxl.Workbook()

# %%
hoja = wb.active

# %%
for producto in codigos:
    # producto es una tupla con los valores de un producto 
    hoja.append(producto)

# %%
wb.save('reporte104.xlsx')
