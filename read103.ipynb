    print(separado)
    con = 0
    
    for it in separado:
        if it == "Período Fiscal:":
            per = separado[con+1]
        if it=="302":
            valcod302 = separado[con+1]
        if it=="352":
            valcod352 = separado[con+1]
        if it=="303":
            valcod303 = separado[con+1]
        if it=="353":
            valcod353 = separado[con+1]
            
        if it=="304":
            valcod304 = separado[con+1]
        if it=="354":
            valcod354 = separado[con+1]
            
        if it=="305":
            valcod305 = separado[con+1]
        if it=="306":
            valcod306 = separado[con+1]
        if it=="307":
            valcod307 = separado[con+1]
        if it=="357":
            valcod357 = separado[con+1]
            
        if it=="308":
            valcod308 = separado[con+1]
        if it=="358":
            valcod358 = separado[con+1]
            
        if it=="309":
            valcod309 = separado[con+1]
        if it=="359":
            valcod359 = separado[con+1]
            
        if it=="310":
            valcod310 = separado[con+1]
        if it=="360":
            valcod360 = separado[con+1]
            
        if it=="311":
            valcod311 = separado[con+1]
        if it=="361":
            valcod361 = separado[con+1]
            
        if it=="312":
            valcod312 = separado[con+1]
        if it=="362":
            valcod362 = separado[con+1]
            
        if it=="314":
            valcod314 = separado[con+1]
        if it=="364":
            valcod364 = separado[con+1]
            
        if it=="319":
            valcod319 = separado[con+1]
        if it=="369":
            valcod369 = separado[con+1]
        
        if it=="320":
            valcod320 = separado[con+1]
        if it=="370":
            valcod370 = separado[con+1]
                
        if it=="322":
            valcod322= separado[con+1]
        if it=="372":
            valcod372= separado[con+1]
            
        if it=="323":
            valcod323= separado[con+1]
        if it=="373":
            valcod373= separado[con+1]
            
        if it=="324":
            valcod324= separado[con+1]
        if it=="374":
            valcod374= separado[con+1]
            
        if it=="325":
            valcod325= separado[con+1]
        if it=="375":
            valcod375= separado[con+1]
            
        if it=="326":
            valcod326= separado[con+1]
        if it=="376":
            valcod376= separado[con+1]    
        
        if it=="327":
            valcod327= separado[con+1]
        if it=="377":
            valcod377= separado[con+1]
            
        if it=="328":
            valcod328= separado[con+1]
        if it=="378":
            valcod378= separado[con+1]
        
        con+=1
        
    pag.append("Período Fiscal: "+per)
    pag.append(valcod302)
    pag.append(valcod352)
    
    pag.append(valcod303)
    pag.append(valcod353)
    
    pag.append(valcod304)
    pag.append(valcod354)

    pag.append(valcod307)
    pag.append(valcod357)
    
    pag.append(valcod308)
    pag.append(valcod358)
    
    pag.append(valcod309)
    pag.append(valcod359)
    
    pag.append(valcod310)
    pag.append(valcod360)
    
    pag.append(valcod311)
    pag.append(valcod361)
    
    pag.append(valcod312)
    pag.append(valcod362)

    pag.append(valcod314)
    pag.append(valcod364)
    
    pag.append(valcod319)
    pag.append(valcod369)
    
    pag.append(valcod320)
    pag.append(valcod370)
    
    pag.append(valcod322)
    pag.append(valcod372)
    
    pag.append(valcod323)
    pag.append(valcod373)
    
    pag.append(valcod324)
    pag.append(valcod374)
    
    pag.append(valcod325)
    pag.append(valcod375)
    
    pag.append(valcod326)
    pag.append(valcod376)
    
    pag.append(valcod327)
    pag.append(valcod377)
    
    pag.append(valcod328)
    pag.append(valcod378)

    total302=float(total302)+float(valcod302)
    total352=float(total352)+float(valcod352)
    
    total303=float(total303)+float(valcod303)
    total353=float(total353)+float(valcod353)
    
    total304=float(total304)+float(valcod304)
    total354=float(total354)+float(valcod354)

    total307=float(total307)+float(valcod307)
    total357=float(total357)+float(valcod357)
    
    total308=float(total308)+float(valcod308)
    total358=float(total358)+float(valcod358)
    
    total309=float(total309)+float(valcod309)
    total359=float(total359)+float(valcod359)
    
    total310=float(total310)+float(valcod310)
    total360=float(total360)+float(valcod360)
    
    total311=float(total311)+float(valcod311)
    total361=float(total361)+float(valcod361)
    
    total312=float(total312)+float(valcod312)
    total362=float(total362)+float(valcod362)

    total314=float(total314)+float(valcod314)
    total364=float(total364)+float(valcod364)
    
    total319=float(total319)+float(valcod319)
    total369=float(total369)+float(valcod369)
    
    total320=float(total320)+float(valcod320)
    total370=float(total370)+float(valcod370)
    
    total322=float(total322)+float(valcod322)
    total372=float(total372)+float(valcod372)
    
    total323=float(total323)+float(valcod323)
    total373=float(total373)+float(valcod373)
    
    total324=float(total324)+float(valcod324)
    total374=float(total374)+float(valcod374)
    
    total325=float(total325)+float(valcod325)
    total375=float(total375)+float(valcod375)
    
    total326=float(total326)+float(valcod326)
    total376=float(total376)+float(valcod376)
    
    total327=float(total327)+float(valcod327)
    total377=float(total377)+float(valcod377)
    
    total328=float(total328)+float(valcod328)
    total378=float(total378)+float(valcod378)

        
    pagina = documento.loadPage(1)
    text = pagina.getText("Text")
    
    separador = "\n"
    separado = text.split(separador)
    print(separado)
    con = 0
    
    for it in separado:
        if it=="329":
            valcod302 = separado[con+1]
        if it=="379":
            valcod379 = separado[con+1]
            
        if it=="330":
            valcod330 = separado[con+1]
        if it=="380":
            valcod380 = separado[con+1]

        if it=="331":
            valcod331 = separado[con+1]
        
        if it=="332":
            valcod332 = separado[con+1]

        if it=="333":
            valcod333= separado[con+1]
        if it=="383":
            valcod383= separado[con+1]    
        
        if it=="334":
            valcod334= separado[con+1]
        if it=="384":
            valcod384= separado[con+1]
            
        if it=="335":
            valcod335= separado[con+1]
        if it=="385":
            valcod385= separado[con+1]
            
        if it=="336":
            valcod336= separado[con+1]
        if it=="386":
            valcod386= separado[con+1]
            
        if it=="337":
            valcod337= separado[con+1]
        if it=="387":
            valcod387= separado[con+1]
            
        if it=="338":
            valcod338= separado[con+1]
        if it=="388":
            valcod388= separado[con+1]
            
            
        if it=="3380":
            valcod3380= separado[con+1]
        if it=="3880":
            valcod3880= separado[con+1]    
        
        if it=="339":
            valcod339 = separado[con+1]
        if it=="389":
            valcod389 = separado[con+1]    
        
        if it=="340":
            valcod340 = separado[con+1]
        if it=="390":
            valcod390 = separado[con+1]
            
        if it=="341":
            valcod341 = separado[con+1]
        if it=="391":
            valcod391 = separado[con+1]
            
        if it=="342":
            valcod342 = separado[con+1]
        if it=="392":
            valcod392 = separado[con+1]    
        
        if it=="343":
            valcod343 = separado[con+1]
        if it=="393":
            valcod393 = separado[con+1]
            
        if it=="344":
            valcod344 = separado[con+1]
        if it=="394":
            valcod394 = separado[con+1]
            
        if it=="345":
            valcod345 = separado[con+1]
        if it=="395":
            valcod395 = separado[con+1]
            
        if it=="346":
            valcod346 = separado[con+1]
        if it=="396":
            valcod396 = separado[con+1]
            
        if it=="348":
            valcod348 = separado[con+1]
        if it=="398":
            valcod398 = separado[con+1]
            
        if it=="349":
            valcod349 = separado[con+1]
        if it=="399":
            valcod399 = separado[con+1]
        con+=1
            
    
    total329=total329+float(valcod329)
    total379=total379+float(valcod379)
    
    total330=total330+float(valcod330)
    total380=total380+float(valcod380)
    
    total331=total331+float(valcod331)
    total332=total332+float(valcod332)
    
    total333=total333+float(valcod333)
    total383=total383+float(valcod383)
    
    total334=total334+float(valcod334)
    total384=total384+float(valcod384)
    
    total335=total335+float(valcod335)
    total385=total385+float(valcod385)
    
    total336=total336+float(valcod336)
    total386=total386+float(valcod386)
    
    total337=total337+float(valcod337)
    total387=total387+float(valcod387)
    
    total3380=total3380+float(valcod3380)
    total338=total338+float(valcod338)
    total388=total388+float(valcod388)
    
    total339=total339+float(valcod339)
    total389=total389+float(valcod389)
    
    total340=total340+float(valcod340)
    total390=total390+float(valcod390)
    
    total341=total341+float(valcod341)
    total391=total391+float(valcod391)
    
    total342=total342+float(valcod342)
    total392=total392+float(valcod392)
    
    total343=total343+float(valcod343)
    total393=total393+float(valcod393)
    
    total344=total344+float(valcod344)
    total394=total394+float(valcod394)
    
    total345=total345+float(valcod345)
    total395=total395+float(valcod395)
    
    total346=total346+float(valcod346)
    total396=total396+float(valcod396)
    
    total348=total348+float(valcod348)
    total348=total398+float(valcod398)
    
    total349=total349+float(valcod349)
    total399=total399+float(valcod399)
            
      
    pag.append(valcod329)
    pag.append(valcod379)
    
    pag.append(valcod330)
    pag.append(valcod380)
    
    pag.append(valcod331)
    pag.append(valcod332)
    pag.append(valcod333)
    pag.append(valcod383)
    
    pag.append(valcod334)
    pag.append(valcod384)
    
    pag.append(valcod335)
    pag.append(valcod385)
    
    pag.append(valcod336)
    pag.append(valcod386)
    
    pag.append(valcod337)
    pag.append(valcod387)
    
    pag.append(valcod338)
    pag.append(valcod388)
    
    pag.append(valcod3380)
    pag.append(valcod339)
    pag.append(valcod389)
    
    pag.append(valcod340)
    pag.append(valcod390)
    
    pag.append(valcod341)
    pag.append(valcod391)
    
    pag.append(valcod342)
    pag.append(valcod392)
    
    pag.append(valcod343)
    pag.append(valcod393)
    
    pag.append(valcod344)
    pag.append(valcod394)
    
    pag.append(valcod345)
    pag.append(valcod395)
    
    pag.append(valcod346)
    pag.append(valcod396)
    
    pag.append(valcod348)
    pag.append(valcod398)
    
    pag.append(valcod349)
    pag.append(valcod399)


    ###########################
    pagina = documento.loadPage(2)
    text = pagina.getText("Text")
    
    separador = "\n"
    separado = text.split(separador)
    #print(separado)
    con = 0
    
    for it in separado:
        if it=="405":
            valcod405 = separado[con+1]
            print("________________")
            print(valcod405)
            
        if it=="406":
            valcod406 = separado[con+1]
        if it=="456":
            valcod456 = separado[con+1]

        if it=="407":
            valcod407 = separado[con+1]
        if it=="457":
            valcod457 = separado[con+1]

        if it=="408":
            valcod408 = separado[con+1]
        if it=="458":
            valcod458 = separado[con+1]

        if it=="409":
            valcod409= separado[con+1]
        if it=="459":
            valcod459= separado[con+1]
            
        if it=="410":
            valcod410= separado[con+1]
        if it=="460":
            valcod460= separado[con+1]
            
        if it=="411":
            valcod411= separado[con+1]
        if it=="461":
            valcod461= separado[con+1]
            
        if it=="412":
            valcod412= separado[con+1]
                
        if it=="413":
            valcod413= separado[con+1]
        if it=="463":
            valcod463= separado[con+1]
            
        if it=="414":
            valcod414= separado[con+1]
        if it=="464":
            valcod464= separado[con+1]
            
        if it=="415":
            valcod415= separado[con+1]
        if it=="465":
            valcod465= separado[con+1]
            
        if it=="416":
            valcod416= separado[con+1]
        if it=="416":
            valcod466=separado[con+1]
            
        if it=="417":
            valcod417= separado[con+1]
        if it=="467":
            valcod467= separado[con+1]
        
        if it=="418":
            valcod418 = separado[con+1]
        if it=="468":
            valcod468 = separado[con+1]
            
        if it=="419":
            valcod419 = separado[con+1]
        if it=="469":
            valcod469 = separado[con+1]
            
        if it=="420":
            valcod420 = separado[con+1]
        if it=="470":
            valcod470 = separado[con+1]
            
        if it=="421":
            valcod421 = separado[con+1]
        if it=="471":
            valcod471 = separado[con+1]
            
        if it=="422":
            valcod422 = separado[con+1]
        if it=="472":
            valcod472 = separado[con+1]
            
        if it=="423":
            valcod423 = separado[con+1]
        if it=="473":
            valcod473 = separado[con+1]
            
        if it=="424":
            valcod424 = separado[con+1]
        if it=="474":
            valcod474 = separado[con+1]
            
        if it=="425":
            valcod425 = separado[con+1]
        if it=="475":
            valcod475 = separado[con+1]
            
        if it=="426":
            valcod426 = separado[con+1]
        if it=="476":
            valcod476 = separado[con+1]
            
        if it=="427":
            valcod427 = separado[con+1]
        if it=="477":
            valcod477 = separado[con+1]    
        
        if it=="428":
            valcod428 = separado[con+1]
        if it=="478":
            valcod478 = separado[con+1]
            
        if it=="429":
            valcod429 = separado[con+1]
        if it=="479":
            valcod479 = separado[con+1]
            
        if it=="430":
            valcod430 = separado[con+1]
        if it=="480":
            valcod480 = separado[con+1]
            
        if it=="431":
            valcod431 = separado[con+1]
        if it=="481":
            valcod481 = separado[con+1]
            
        if it=="432":
            valcod432 = separado[con+1]
        if it=="482":
            valcod482 = separado[con+1]
            
        if it=="433":
            valcod433 = separado[con+1]
        if it=="483":
            valcod483 = separado[con+1]
            
        if it=="497":
            valcod497 = separado[con+1]
        if it=="498":
            valcod498 = separado[con+1]
            
        con+=1
    
    total405=total405+float(valcod405)
    
    total406=total406+float(valcod406)
    total456=total456+float(valcod456)
    
    total407=total407+float(valcod407)
    total457=total457+float(valcod457)
    
    total408=total408+float(valcod408)
    total458=total458+float(valcod458)
    
    total409=total409+float(valcod409)
    total459=total459+float(valcod459)
    
    total410=total410+float(valcod410)
    total460=total460+float(valcod460)
    
    total411=total411+float(valcod411)
    total461=total461+float(valcod461)
    total412=total412+float(valcod412)
    
    total413=total413+float(valcod413)
    total463=total463+float(valcod463)
    
    total414=total414+float(valcod414)
    total464=total464+float(valcod464)
    
    total415=total415+float(valcod415)
    total465=total465+float(valcod465)
    
    total416=total416+float(valcod416)
    total466=total466+float(valcod466)
    
    total417=total417+float(valcod417)
    total467=total467+float(valcod467)
    
    total418=total418+float(valcod418)
    total468=total468+float(valcod468)
    
    total419=total419+float(valcod419)
    total469=total469+float(valcod469)
    
    total420=total420+float(valcod420)
    total470=total470+float(valcod470)
    
    total421=total421+float(valcod421)
    total471=total471+float(valcod471)
    
    total422=total422+float(valcod422)
    total472=total472+float(valcod472)
    
    total423=total423+float(valcod423)
    total473=total473+float(valcod473)
    
    total424=total424+float(valcod424)
    total474=total474+float(valcod474)
    
    total425=total425+float(valcod425)
    total475=total475+float(valcod475)
    
    total426=total426+float(valcod426)
    total476=total476+float(valcod476)
    
    total427=total427+float(valcod427)
    total477=total477+float(valcod477)
    
    total428=total428+float(valcod428)
    total478=total478+float(valcod478)
    
    total429=total429+float(valcod429)
    total479=total479+float(valcod479)
    
    total430=total430+float(valcod430)
    total480=total480+float(valcod480)
    
    total431=total431+float(valcod431)
    total481=total481+float(valcod481)
    
    total432=total432+float(valcod432)
    total482=total482+float(valcod482)
    
    total433=total433+float(valcod433)
    total483=total483+float(valcod483)
    
    total497=total497+float(valcod497)
    total498=total498+float(valcod498)

    print("total "+str(total349))
    
    pag.append(valcod405)
    pag.append(valcod406)
    pag.append(valcod456)
    
    pag.append(valcod407)
    pag.append(valcod457)
    
    pag.append(valcod408)
    pag.append(valcod458)
    
    pag.append(valcod409)
    pag.append(valcod459)
    
    pag.append(valcod410)
    pag.append(valcod460)
    
    pag.append(valcod411)
    pag.append(valcod461)
    
    pag.append(valcod412)
    pag.append(valcod413)
    pag.append(valcod463)
    
    pag.append(valcod414)
    pag.append(valcod464)
    
    pag.append(valcod415)
    pag.append(valcod465)
    
    pag.append(valcod416)
    pag.append(valcod466)
    
    pag.append(valcod417)
    pag.append(valcod467)
    
    pag.append(valcod418)
    pag.append(valcod468)
    
    pag.append(valcod419)
    pag.append(valcod469)
    
    pag.append(valcod420)
    pag.append(valcod470)
    
    pag.append(valcod421)
    pag.append(valcod471)
    
    pag.append(valcod422)
    pag.append(valcod472)
    
    pag.append(valcod423)
    pag.append(valcod473)
    
    pag.append(valcod424)
    pag.append(valcod474)
    
    pag.append(valcod425)
    pag.append(valcod475)
    
    pag.append(valcod426)
    pag.append(valcod476)
    
    pag.append(valcod427)
    pag.append(valcod477)
    
    pag.append(valcod428)
    pag.append(valcod478)
    
    pag.append(valcod429)
    pag.append(valcod479)
    
    pag.append(valcod430)
    pag.append(valcod480)
    
    pag.append(valcod431)
    
    pag.append(valcod432)
    
    pag.append(valcod433)
    pag.append(valcod483)
    
    pag.append(valcod497)
    pag.append(valcod498)
    
    
    ####Pendiente desde aqui
    codigos.append(pag)
    
    
total.append("Total")
total.append(total302)
total.append(total352)
total.append(total303)
total.append(total353)
total.append(total304)
total.append(total354)
    
total.append(total307)
total.append(total357)
total.append(total308)
total.append(total358)
total.append(total309)
total.append(total359)
total.append(total310)
total.append(total360)
total.append(total311)
total.append(total361)
total.append(total312)
total.append(total362)
    
total.append(total314)
total.append(total364)
total.append(total319)
total.append(total369)
total.append(total320)
total.append(total370)
total.append(total322)
total.append(total372)
total.append(total323)
total.append(total373)
total.append(total324)
total.append(total374)
total.append(total325)
total.append(total375)
total.append(total326)
total.append(total376)
total.append(total327)
total.append(total377)
total.append(total328)
total.append(total378)

total.append(total329)
total.append(total379)
total.append(total330)
total.append(total380)
total.append(total331)
total.append(total332)
total.append(total333)
total.append(total383)
total.append(total334)
total.append(total384)
total.append(total335)
total.append(total385)
total.append(total336)
total.append(total386)
total.append(total337)
total.append(total387)
total.append(total338)
total.append(total388)
total.append(total3380)

total.append(total339)
total.append(total389)
total.append(total340)
total.append(total390)
total.append(total341)
total.append(total391)
total.append(total342)
total.append(total392)
total.append(total343)
total.append(total393)
total.append(total344)
total.append(total394)
total.append(total345)
total.append(total395)
total.append(total346)
total.append(total396)
total.append(total348)
total.append(total398)
total.append(total349)
total.append(total399)

total.append(total405)

total.append(total406)
total.append(total456)
total.append(total407)
total.append(total457)
total.append(total408)
total.append(total458)
total.append(total409)
total.append(total459)
total.append(total410)
total.append(total460)
total.append(total411)
total.append(total461)
total.append(total412)

total.append(total413)
total.append(total463)
total.append(total414)
total.append(total464)
total.append(total415)
total.append(total465)
total.append(total416)
total.append(total466)
total.append(total417)
total.append(total467)
total.append(total418)
total.append(total468)
total.append(total419)
total.append(total469)
total.append(total420)
total.append(total470)
total.append(total421)
total.append(total471)
total.append(total422)
total.append(total472)
total.append(total423)
total.append(total473)
total.append(total424)
total.append(total474)
total.append(total425)
total.append(total475)
total.append(total426)
total.append(total476)
total.append(total427)
total.append(total477)
total.append(total428)
total.append(total478)
total.append(total429)
total.append(total479)
total.append(total430)
total.append(total480)
total.append(total431)
total.append(total432)
total.append(total433)
total.append(total483)
total.append(total497)
total.append(total498)

codigos.append(total)
'''
print(total329)
print(total330)
print(total331)
print(total332)
print(total333)
print(total334)
print(total335)
print(total336)
print(total337)
print(total3380)
print(total338)
print(total339)
print(total340)
print(total341)
print(total342)
print(total343)
print(total344)
print(total345)
print(total346)
print(total348)
print(total349)
print(total405)
print(total406)
print(total407)
print(total408)
print(total409)
print(total410)
print(total411)
print(total412)
print(total413)
print(total414)
print(total415)
print(total416)
print(total417)
print(total418)
print(total419)
print(total420)
print(total421)
print(total422)
print(total423)
print(total424)
print(total425)
print(total426)
print(total427)
print(total428)
print(total429)
print(total430)
print(total431)
print(total432)
print(total433)
print(total497)
print(codigos)'''
# Out:
# formularios/Declaracion_871947279219(103).pdf
# ...

# %%
    "myData = [[302,304.89],[340, 50.03]]"""
    
    #print((codigos))
    #print(myData)
    #newDat = str(codigos)
    #print(newDat)
    #myData = codigos
    
    """myFile = open('reporte103.csv', 'w')
    with myFile:
        writer = csv.writer(myFile)
        writer.writerows(myData)

    print("Writing complete")"""
# Out:
# 'myFile = open(\'reporte103.csv\', \'w\')\nwith myFile:\n    writer = csv.writer(myFile)\n    writer.writerows(myData)\n\nprint("Writing complete")'

# %%
import openpyxl
wb = openpyxl.Workbook()

# %%
hoja = wb.active

# %%
for producto in codigos:
    # producto es una tupla con los valores de un producto 
    hoja.append(producto)

# %%
wb.save('Procesados/10ENCOMPRO/reporte103.xlsx')
